# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-10,10,100)

# %%
n = 3
m = 2
4*(m//2)*(n+m//2)
# Out:
# 16

# %%
axes = plt.subplots(ncols=2)[1]
axes[0].plot(x,(x//2)**2)
axes[1].plot(x,x**2//4)
